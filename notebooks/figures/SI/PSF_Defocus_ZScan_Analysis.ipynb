# %% [markdown]
# # PSF Defocus Z-Scan Analysis
#
# Vectorial Debye PSF simulation sweep for **ATTO 488**, **ATTO 565**, and **ATTO 647N**.
# Quantifies the effect of axial defocus on localisation precision and colour precision
# using the standard S3M fitting pipeline (`FittingStrategy.STANDARD`).
#
# Physics model: vectorial Debye + Gibson–Lanni spherical aberration (NA 1.49, oil/water).
#
# **Structure**
# 1. PSF shape visualisation — per-channel (B/G/R) RGB composite at increasing defocus
# 2. Z-sweep simulation — 7 z-offsets × 2 coverslip depths × 3 photon levels
# 3. Analysis — localisation precision and colour precision vs defocus

# %%
import sys, os, glob, types
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import polars as pl


from pyS3M import IOFunctions, SpectralFunctions, MaskFunctions, sCMOSFunctions, PlottingBase
from pyS3M.Multicolour_Simulation_Functions import (
    FittingStrategy, SimulationConfig, MultiC_Sim_Funcs,
)
from pyS3M.simulation.defocus_psf import VectorialPSF

IO    = IOFunctions.IO_Functions()
S_F   = SpectralFunctions.Spectral_Funcs()
M_F   = MaskFunctions.Mask_Functions()
sCMOS = sCMOSFunctions.sCMOS_Functions()
MSF   = MultiC_Sim_Funcs()
plotter = PlottingBase.PublicationPlotter()

# %%
# ── Camera calibration ────────────────────────────────────────────────────────
cal_folder = Path("../../../Camera_Calibrations/Ximea_Camera/")
gain      = IO.read_tiff(str(cal_folder / "gain.tif"))
offset    = IO.read_tiff(str(cal_folder / "offset.tif"))
variance  = IO.read_tiff(str(cal_folder / "variance.tif"))
readnoise = float(np.median(IO.read_tiff(str(cal_folder / "readnoise.tif"))))
rqe       = IO.read_tiff(str(cal_folder / "rqe.tif"))

print(f"Camera calibration loaded — sensor: {gain.shape}, readnoise: {readnoise:.2f}")
# Out:
# Camera calibration loaded — sensor: (1544, 2064), readnoise: 2.34

# %%
# ── Spectral setup ────────────────────────────────────────────────────────────
R, G, B, wavelength = S_F.getpixelefficiency()
pixel_QYs = np.vstack([B, G, R])   # (3, n_wl); convention B=0, G=1, R=2

# Dyes and global simulation constants
dyes          = ["ATTO 488", "ATTO 565", "ATTO 647N"]
filters       = []          # no bandpass filter
NA            = 1.49
pixel_size_nm = 69.0        # Ximea object-space pixel (nm)
image_dims    = 32          # 22 × 22 px  ≈  1.52 µm FOV
background_photons = 5.0

# Smoothing function (Gaussian, σ = 1.5 px) ─ must be defined before MSF calls
smoothing_function = types.SimpleNamespace(
    args={"sigma": 1.5},
    extent=1.5,
    smoothing_function=sCMOS.gaussian_filter_stack,
    data_arg="image",
)

# Coarser wavelength grid for PSF integration (5 nm steps; sufficient to <1% PSF error)
wl_psf_nm = np.arange(400, 751, 5, dtype=float)

# build_spectral_weights requires pixel_QYs on the same grid as wl_psf_nm;
# the native grid from getpixelefficiency() may differ — interpolate.
pixel_QYs_psf = np.vstack([
    np.interp(wl_psf_nm, wavelength, pixel_QYs[c])
    for c in range(pixel_QYs.shape[0])
])  # (3, len(wl_psf_nm))

print(f"Wavelength grid: {wavelength[0]:.0f}–{wavelength[-1]:.0f} nm  "
      f"({len(wavelength)} pts);  PSF grid: {len(wl_psf_nm)} pts @ 5 nm steps")
# Out:
# Wavelength grid: 400–999 nm  (600 pts);  PSF grid: 71 pts @ 5 nm steps

# %%
# ── Save folder ───────────────────────────────────────────────────────────────
save_folder = Path("/scratch/sycamore-asap/ASAP_Members_Other_Imaging_Data/JSB/Simulation/Z_Position_Effect")
save_folder.mkdir(parents=True, exist_ok=True)
print(f"Results → {save_folder}")
# Out:
# Results → /scratch/sycamore-asap/ASAP_Members_Other_Imaging_Data/JSB/Simulation/Z_Position_Effect

# %%
# ── VectorialPSF objects and per-dye spectral weights ─────────────────────────
# N_pupil=128 is fast enough for the display figure; simulation dispatch uses 256
vpsf_display = VectorialPSF(
    NA=NA, n_medium=1.33, n_immersion=1.515,
    pix_obj_um=pixel_size_nm / 1000.0,
    psf_size=21, N_pupil=256,
)

# Spectral weights: w_c(λ) = S(λ)·T_obj(λ)·QE_c(λ), shape (n_wl_psf, 3) = (n_wl_psf, B/G/R)
# pixel_QYs_psf is already interpolated to wl_psf_nm in the spectral setup cell.
spectral_weights = {}
channel_fractions = {}
for dye in dyes:
    w = VectorialPSF.build_spectral_weights(
        spectral_functions=S_F,
        dye=dye,
        filters=None,
        wavelengths_nm=wl_psf_nm,
        pixel_QYs=pixel_QYs_psf,   # (3, n_wl_psf) — matched grid
        include_objective=True,
    )  # (n_wl_psf, 3)
    spectral_weights[dye] = w
    frac = w.sum(axis=0) / w.sum()
    channel_fractions[dye] = frac
    print(f"{dye:12s}  B={frac[0]:.3f}  G={frac[1]:.3f}  R={frac[2]:.3f}")
# Out:
# ATTO 488      B=0.143  G=0.745  R=0.112
# ATTO 565      B=0.027  G=0.392  R=0.581
# ATTO 647N     B=0.058  G=0.203  R=0.739

# %% [markdown]
# ## PSF Shape Visualisation
#
# Polychromatic vectorial PSF at each defocus step, integrated over the dye emission
# spectrum weighted by per-channel Bayer QE.  Each panel is an **RGB composite**:
# B-channel PSF → blue, G-channel PSF → green, R-channel PSF → red.
# Intensities are normalised to the peak of the **in-focus** PSF for that channel,
# so dimming of the central peak with defocus is visible.

# %%
# ── Compute PSF patches for visualisation ────────────────────────────────────
z_display_nm = np.array([0, 100, 200, 300, 500], dtype=float)
z_display_um = z_display_nm / 1000.0
wl_display_um = wl_psf_nm / 1000.0

psf_display = {}    # psf_display[dye] shape: (n_z, 3, psf_size, psf_size)
for dye in dyes:
    psf_display[dye] = vpsf_display.compute_psf_stack(
        z_offsets_um=z_display_um,
        wavelengths_um=wl_display_um,
        spectral_weights=spectral_weights[dye],
        distance_from_coverslip_um=0.0,
    )  # (n_z, 3, 21, 21)
    print(f"{dye} PSF stack: {psf_display[dye].shape}  "
          f"in-focus B/G/R peak: {psf_display[dye][0].max(axis=(-2,-1))}")
# Out:
# ATTO 488 PSF stack: (5, 3, 21, 21)  in-focus B/G/R peak: [ 0.10259745  0.09842277  0.0861318 ]
# ATTO 565 PSF stack: (5, 3, 21, 21)  in-focus B/G/R peak: [ 0.07579674  0.0801893   0.07555175]
# ATTO 647N PSF stack: (5, 3, 21, 21)  in-focus B/G/R peak: [ 0.06228398  0.06149628  0.06293099]

# %%
# ── Figure 1: raw vectorial PSF at increasing defocus ────────────────────────
# |FFT(E)|² from the Debye model: no noise, no camera QE, no Bayer mask.
# 25 nm/pixel oversamples the Airy disk (~9 px across) to show ring structure.
# Each panel normalised to its own peak to reveal structure at every defocus.

# pix_raw_nm   = 5.0
# psf_size_raw = int(3000/5)          # 81 × 25 nm = 2.025 µm window

# vpsf_raw = VectorialPSF(
#     NA=NA, n_medium=1.33, n_immersion=1.515,
#     pix_obj_um=pix_raw_nm / 1000.0,
#     psf_size=psf_size_raw,
#     N_pupil=512,
# )

# z_disp_raw_nm = np.array([0, 100, 250, 500], dtype=float)

# psf_raw_stack = vpsf_raw.compute_psf_stack(
#     z_offsets_um=z_disp_raw_nm / 1000.0,
#     wavelengths_um=np.array([0.55]),
#     spectral_weights=None,
#     distance_from_coverslip_um=0.0,
# )  # (n_z, 1, ps, ps)

# n_z_raw = len(z_disp_raw_nm)

# fig, axs = plotter.two_column_plot(nrows=1, ncols=n_z_raw, height=6.69 / n_z_raw + 0.05)
# fs = plotter.config.font_size

# for i_z in range(n_z_raw):
#     I = psf_raw_stack[i_z, 0]
#     I_disp = I / I.max()
#     I_log = np.log10(np.maximum(I_disp, 1e-4))   # floor avoids log(0)
#     plotter.image_plot(
#         axs[i_z], I_log,
#         cmap="gray",
#         vmin=np.percentile(I_log, 0.1), vmax=np.percentile(I_log, 99.9),
#         scalebar=True,
#         pixelsize=pix_raw_nm,
#         scalebarsize=500.0,
#         scalebarlabel="500 nm",
#         scalebar_color="white",
#         origin="lower",
#         colorbar=(i_z == 3)
#     )

#     # In-panel annotation: defocus label in top-left corner
#     label = f"Δz = {z_disp_raw_nm[i_z]:.0f} nm"
#     axs[i_z].text(
#         0.05, 0.97, label,
#         transform=axs[i_z].transAxes,
#         fontsize=fs, color="white",
#         va="top", ha="left",
#         bbox=dict(boxstyle="square,pad=0.15", fc="none", ec="none"),
#     )

# plotter.save_or_show(fig, save_path=str(save_folder / "psf_defocus_raw.svg"), show=False)

# %% [markdown]
# ## Z-Sweep Simulation
#
# For each (dye, z-offset), run `test_simulation_method` with `FittingStrategy.STANDARD`
# across 100 photon levels.  Emitter at the coverslip (no spherical aberration).
#
# Z-offset range: **−1000 to +1000 nm** in 100 nm steps (21 values).
# Negative z = emitter below focus; positive z = emitter above focus.

# %%
# ── Sweep parameters ─────────────────────────────────────────────────────────
z_offsets_nm        = np.arange(-1000, 1001, 100, dtype=float)   # 21 values: -1000..+1000 nm
coverslip_depths_nm = np.array([0.0], dtype=float)                # at coverslip only
n_photon_space      = np.geomspace(500, 20000, 100)
n_bootstrap         = 10000

print(f"Sweep:  {len(dyes)} dyes  ×  {len(z_offsets_nm)} z-offsets  "
      f"×  {len(coverslip_depths_nm)} coverslip depth  "
      f"×  {len(n_photon_space)} photon levels")
print(f"Total simulation calls: "
      f"{len(dyes) * len(z_offsets_nm) * len(coverslip_depths_nm)}")
# Out:
# Sweep:  3 dyes  ×  21 z-offsets  ×  1 coverslip depth  ×  100 photon levels
# Total simulation calls: 63

# %%
# ── Camera parameters dictionary (constant across sweep) ─────────────────────
def make_camera_params(image_dims):
    """Median-flat camera calibration for a square image of size image_dims."""
    return {
        "gain":               np.full((image_dims, image_dims), np.median(gain)),
        "offset":             np.full((image_dims, image_dims), np.median(offset)),
        "variance":           np.full((image_dims, image_dims), np.median(variance)),
        "readnoise":          readnoise,
        "rqe":                np.full((image_dims, image_dims), np.median(rqe)),
        "masks":              M_F.get_masks(size_x=image_dims, size_y=image_dims),
        "pixel_QYs":          pixel_QYs,
        "pixel_order":        ["B", "G", "R"],
        "pixel_order_indices": {"B": 0, "G": 1, "R": 2},
    }

camera_params_dict = make_camera_params(image_dims)
print(f"Camera parameters dict ready — image size: {image_dims}×{image_dims} px")
# Out:
# Camera parameters dict ready — image size: 32×32 px

# %%
# ── Run sweep ─────────────────────────────────────────────────────────────────
import time

def _flag_nm(val: float) -> str:
    """Format an integer-nm defocus value for use in a filename flag.

    Non-negative values get 'p' prefix, negative values get 'm' prefix,
    followed by a zero-padded 4-digit integer magnitude.
    Examples: -1000 → 'm1000', 0 → 'p0000', 100 → 'p0100'.
    """
    sign = "m" if val < 0 else "p"
    return f"{sign}{int(round(abs(val))):04d}"

n_total  = len(dyes) * len(z_offsets_nm) * len(coverslip_depths_nm)
i_run    = 0
t_start  = time.time()

for dye in dyes:
    for z_nm in z_offsets_nm:
        for d_nm in coverslip_depths_nm:
            i_run += 1
            flag = f"defocus_z{_flag_nm(z_nm)}nm_d{_flag_nm(d_nm)}nm_"

            config = SimulationConfig(
                n_bootstrap=n_bootstrap,
                background_photons=background_photons,
                NA=NA,
                pixel_size=pixel_size_nm,
                save_raw_results=True,
                subtractx0y0=False,
                use_stochastic_photons=True,
                save_summary_csvs=True,
                verbose=False,
                defocus_z_um=z_nm / 1000.0,
                distance_from_coverslip_um=d_nm / 1000.0,
            )

            print(f"[{i_run:3d}/{n_total}]  {dye}  z={z_nm:+7.1f} nm  "
                  f"d={d_nm:4.0f} nm", end="  ", flush=True)

            MSF.test_simulation_method(
                dye=dye,
                filters=filters,
                wavelength=wavelength,
                camera_parameters=camera_params_dict,
                save_folder=str(save_folder),
                n_photon_space=n_photon_space,
                smoothing_function=smoothing_function,
                strategy=FittingStrategy.STANDARD,
                starting_flag=flag,
                config=config,
                overwrite=True,
            )

            elapsed = (time.time() - t_start) / 60.0
            rate    = i_run / elapsed if elapsed > 0 else 0
            eta     = (n_total - i_run) / rate if rate > 0 else 0
            print(f"done   ({elapsed:.1f} min elapsed, ETA {eta:.1f} min)")

print(f"\nSweep complete in {(time.time()-t_start)/60:.1f} min.")
# Out:
# [  1/63]  ATTO 488  z=-1000.0 nm  d=   0 nm
# /home/jsb92/Documents/venv/lib/python3.12/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.291 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (18.3 min elapsed, ETA 1134.3 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 22.131 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (40.4 min elapsed, ETA 1233.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.492 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (58.9 min elapsed, ETA 1178.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 22.291 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (81.2 min elapsed, ETA 1198.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.473 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (99.7 min elapsed, ETA 1156.4 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.513 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (121.2 min elapsed, ETA 1151.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.200 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (139.4 min elapsed, ETA 1115.3 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.986 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (161.4 min elapsed, ETA 1109.6 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.408 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (179.8 min elapsed, ETA 1078.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 22.113 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (201.9 min elapsed, ETA 1070.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 17.786 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (219.7 min elapsed, ETA 1038.6 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 17.915 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (237.6 min elapsed, ETA 1009.9 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 15.371 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (253.0 min elapsed, ETA 973.1 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 17.581 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (270.6 min elapsed, ETA 947.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 15.748 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (286.3 min elapsed, ETA 916.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 20.934 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (307.3 min elapsed, ETA 902.6 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.530 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (325.8 min elapsed, ETA 881.6 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.468 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (347.3 min elapsed, ETA 868.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.026 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (366.3 min elapsed, ETA 848.3 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.454 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (387.8 min elapsed, ETA 833.7 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.390 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (407.1 min elapsed, ETA 814.3 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.451 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (428.6 min elapsed, ETA 798.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.615 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (448.2 min elapsed, ETA 779.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.035 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (469.2 min elapsed, ETA 762.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 20.225 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (489.5 min elapsed, ETA 744.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.567 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (508.0 min elapsed, ETA 723.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 22.200 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (530.2 min elapsed, ETA 707.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.543 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (549.8 min elapsed, ETA 687.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.508 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (569.3 min elapsed, ETA 667.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.973 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (591.3 min elapsed, ETA 650.4 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 20.079 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (611.4 min elapsed, ETA 631.1 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.892 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (631.3 min elapsed, ETA 611.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 22.000 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (653.3 min elapsed, ETA 593.9 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.720 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (673.0 min elapsed, ETA 574.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 22.085 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (695.1 min elapsed, ETA 556.1 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 19.171 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (714.2 min elapsed, ETA 535.7 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 21.182 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (735.4 min elapsed, ETA 516.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 18.188 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (753.6 min elapsed, ETA 495.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 17.086 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (770.7 min elapsed, ETA 474.3 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 15.423 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (786.1 min elapsed, ETA 452.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.674 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (799.8 min elapsed, ETA 429.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.688 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (813.5 min elapsed, ETA 406.7 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.645 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (827.1 min elapsed, ETA 384.7 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.663 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (840.8 min elapsed, ETA 363.1 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.630 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (854.4 min elapsed, ETA 341.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.610 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (868.0 min elapsed, ETA 320.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.645 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (881.7 min elapsed, ETA 300.1 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.604 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (895.3 min elapsed, ETA 279.8 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.610 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (908.9 min elapsed, ETA 259.7 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.706 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (922.6 min elapsed, ETA 239.9 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.731 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (936.3 min elapsed, ETA 220.3 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.810 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (950.2 min elapsed, ETA 201.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.873 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (964.0 min elapsed, ETA 181.9 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.783 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (977.8 min elapsed, ETA 163.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.736 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (991.5 min elapsed, ETA 144.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.696 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1005.2 min elapsed, ETA 125.7 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.619 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1018.9 min elapsed, ETA 107.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.626 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1032.5 min elapsed, ETA 89.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.598 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1046.1 min elapsed, ETA 70.9 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.628 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1059.7 min elapsed, ETA 53.0 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.630 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1073.3 min elapsed, ETA 35.2 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.627 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1087.0 min elapsed, ETA 17.5 min)
#                                                                                 ?, ?it/s]
# INFO:simulation.multicolour:
# Completed analysis of 100 photon flux values    Total time: 13.634 min
# INFO:simulation.multicolour:Simulation completed for strategy standard
# done   (1100.6 min elapsed, ETA 0.0 min)
#
# Sweep complete in 1100.6 min.

# %% [markdown]
# ## Analysis
#
# Load the RMSE summary CSVs saved by `test_simulation_method` and aggregate into
# an xarray for plotting.
#
# Metrics (from `_compute_fit_statistics`):
# - **`xc`, `yc`** — RMSE of fitted position in nm
# - **`colour_distance`** — mean Euclidean distance of fitted (A_B, A_G, A_R) from truth

# %%
import xarray as xr
import matplotlib.colors as mcolors
import re

# ── Build xarray DataArray from RMSE summary CSVs ─────────────────────────────
metrics = ["sigma_xy", "colour_dist"]

da_defocus = xr.DataArray(
    data=np.full(
        [len(dyes), len(z_offsets_nm), len(coverslip_depths_nm),
         len(n_photon_space), len(metrics)],
        np.nan,
    ),
    coords={
        "dye":          dyes,
        "z_nm":         z_offsets_nm,
        "coverslip_nm": coverslip_depths_nm,
        "n_photons":    n_photon_space,
        "metric":       metrics,
    },
    dims=["dye", "z_nm", "coverslip_nm", "n_photons", "metric"],
)

# Match both flag formats:
#   new: [mp]DDDD  e.g. m1000, p0000, p0100  (sign-prefix + 4-digit integer)
#   old: DDDDD[p.]D  e.g. 0000000, 0005p0    (decimal-separator or integer)
_flag_re = re.compile(
    r"defocus_z([mp]?\d+(?:[p.]\d+)?)nm_d([mp]?\d+(?:[p.]\d+)?)nm_",
    re.IGNORECASE,
)

def _parse_nm(s: str) -> float:
    """Convert a flag component to float nm; handles both old and new formats."""
    if s and s[0].lower() == 'm':
        return -float(s[1:])
    if s and s[0].lower() == 'p' and len(s) > 1 and s[1:].isdigit():
        return float(s[1:])   # new sign-prefix format: p0100 → 100.0
    return float(s.replace("p", "."))  # old decimal-separator: 5p0 → 5.0

def _nearest_idx(arr, val, tol=None):
    idx = int(np.argmin(np.abs(arr - val)))
    if tol is not None and abs(arr[idx] - val) > tol:
        return None
    return idx

n_loaded = 0
missing  = []

for i_dye, dye in enumerate(dyes):
    dye_str = dye.replace("/", "-")
    all_files = sorted(
        glob.glob(str(save_folder / f"defocus_z*nm_d*nm_*{dye_str}*RMSE_mean*.csv"))
    )
    if not all_files:
        missing.append((dye, "all"))
        continue

    for fpath in all_files:
        fname = Path(fpath).name
        m = _flag_re.search(fname)
        if not m:
            continue
        z_val = _parse_nm(m.group(1))
        d_val = _parse_nm(m.group(2))

        i_z = _nearest_idx(z_offsets_nm,       z_val, tol=1.0)
        i_d = _nearest_idx(coverslip_depths_nm, d_val, tol=10.0)
        if i_z is None or i_d is None:
            continue

        df = pl.read_csv(fpath)
        for i_ph, row in enumerate(df.iter_rows(named=True)):
            if i_ph >= len(n_photon_space):
                break
            da_defocus[i_dye, i_z, i_d, i_ph, 0] = float(
                np.sqrt((row["xc"] ** 2 + row["yc"] ** 2) / 2)
            )
            da_defocus[i_dye, i_z, i_d, i_ph, 1] = float(row["colour_distance"])
        n_loaded += 1

if missing:
    print(f"No files found for: {missing}")
n_filled = int(np.sum(~np.isnan(da_defocus.sel(metric="sigma_xy").values)))
print(f"Loaded {n_loaded} CSV files → {n_filled} grid cells filled "
      f"({n_filled / da_defocus.sel(metric='sigma_xy').size * 100:.1f} %)")
da_defocus.to_netcdf(str(save_folder / "defocus_sweep.nc"))
print(f"σ_xy  range : {float(da_defocus.sel(metric='sigma_xy').min()):.1f}–"
      f"{float(da_defocus.sel(metric='sigma_xy').max()):.1f} nm")
print(f"colour range: {float(da_defocus.sel(metric='colour_dist').min()):.4f}–"
      f"{float(da_defocus.sel(metric='colour_dist').max()):.4f}")
# Out:
# Loaded 63 CSV files → 6300 grid cells filled (100.0 %)
# σ_xy  range : 1.2–233.2 nm
# colour range: 0.0108–0.4169

# %%
# ── Plotting helpers ──────────────────────────────────────────────────────────
dye_labels = {"ATTO 488": "ATTO 488", "ATTO 565": "ATTO 565", "ATTO 647N": "ATTO 647N"}
fs = plotter.config.font_size

# Diverging colormap: blue = negative defocus, red = positive, near-white = in-focus (z=0)
_z_cmap  = plt.cm.viridis
_z_norm  = plt.Normalize(vmin=0, vmax=z_offsets_nm.max())
z_colors = [_z_cmap(_z_norm(z)) for z in z_offsets_nm[10:]]

# %%
z_offsets_nm[10:]
# Out:
# array([    0.,   100.,   200.,   300.,   400.,   500.,   600.,   700.,
#          800.,   900.,  1000.])

# %%
# ── Figure 2: localisation precision σ_xy — precision vs photons ─────────────
# One line per defocus value (colour = defocus via coolwarm); one panel per dye.
metric = "sigma_xy"

fig, axs = plotter.two_column_plot(nrows=1, ncols=len(dyes),
                                    width_ratios=np.ones(len(dyes)))
for i_c, dye in enumerate(dyes):
    ax = axs[i_c]
    Z = da_defocus.isel(dye=i_c, coverslip_nm=0).sel(metric=metric).values  # (n_z, n_ph)
    for i_z, z_nm_val in enumerate(z_offsets_nm[10:]):
        if i_z % 2 == 0:
            ax = plotter.line_plot(ax, n_photon_space, Z[i_z+10, :],
                                   color=z_colors[i_z], label=f'{z_nm_val:+.0f} nm')
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.set_xlabel(r'$N_{\mathrm{photons}}$', fontsize=fs)
    ax.set_ylabel(r'$\sigma_{xy}$ / nm' if i_c == 0 else '', fontsize=fs)
    ax.set_title(dye_labels[dye], fontsize=fs)
    ax.tick_params(labelsize=fs - 1)
    ax.set_xlim([np.min(n_photon_space), np.max(n_photon_space)])

plotter.save_or_show(fig, save_path=str(save_folder / "localisation_precision_lines.svg"))
# Out:
# INFO:src.PlottingBase:Plot saved to: /scratch/sycamore-asap/ASAP_Members_Other_Imaging_Data/JSB/Simulation/Z_Position_Effect/localisation_precision_lines.svg

# %%
# ── Figure 3: colour precision — precision vs photons ────────────────────────
metric = "colour_dist"

fig, axs = plotter.two_column_plot(nrows=1, ncols=len(dyes),
                                    width_ratios=np.ones(len(dyes)))
for i_c, dye in enumerate(dyes):
    ax = axs[i_c]
    Z = da_defocus.isel(dye=i_c, coverslip_nm=0).sel(metric=metric).values
    for i_z, z_nm_val in enumerate(z_offsets_nm[10:]):
        if i_z % 2 == 0:
            ax = plotter.line_plot(ax, n_photon_space, Z[i_z+10, :],
                                   color=z_colors[i_z], label=f'{z_nm_val:+.0f} nm')
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.set_xlabel(r'$N_{\mathrm{photons}}$', fontsize=fs)
    ax.set_ylabel(r'$\sigma_{\mathrm{colour}}$ (a.u.)' if i_c == 0 else '', fontsize=fs)
    ax.set_title(dye_labels[dye], fontsize=fs)
    ax.tick_params(labelsize=fs - 1)
    ax.set_xlim([np.min(n_photon_space), np.max(n_photon_space)])

plotter.save_or_show(fig, save_path=str(save_folder / "colour_precision_lines.svg"))
# Out:
# INFO:src.PlottingBase:Plot saved to: /scratch/sycamore-asap/ASAP_Members_Other_Imaging_Data/JSB/Simulation/Z_Position_Effect/colour_precision_lines.svg

# %% [markdown]
# ## Bias Analysis
#
# Bias = systematic offset of the **mean** fit from truth (distinct from precision/RMSE above).
#
# - **Position bias** `bias_xy`: $\sqrt{(\bar\epsilon_x^2 + \bar\epsilon_y^2)/2}$ in nm, where $\bar\epsilon = \text{mean}(x_\text{fit} - x_0)$ across bootstraps.
# - **Colour bias** `colour_bias`: Euclidean distance of the mean normalised fitted colour $\bar f_\text{fit} = \overline{A_\text{BGR}/\sum A}$ from the true BGR fraction $f_\text{true}$.
#
# Both metrics use only valid localisations (positive $\sigma$, within image bounds).

# %%
import pandas as pd
from scipy.spatial.distance import cdist

# ── Build bias DataArray from raw HDF5 + groundtruth/input_params CSVs ────────
# bias_xy     : sqrt((mean_ex^2 + mean_ey^2) / 2)  in nm
# colour_bias : ||mean(A_BGR / sum) − true_BGR||   (normalised fraction space)
metrics_bias = ["bias_xy", "colour_bias"]

da_defocus_bias = xr.DataArray(
    data=np.full(
        [len(dyes), len(z_offsets_nm), len(coverslip_depths_nm),
         len(n_photon_space), len(metrics_bias)],
        np.nan,
    ),
    coords={
        "dye":          dyes,
        "z_nm":         z_offsets_nm,
        "coverslip_nm": coverslip_depths_nm,
        "n_photons":    n_photon_space,
        "metric":       metrics_bias,
    },
    dims=["dye", "z_nm", "coverslip_nm", "n_photons", "metric"],
)

n_loaded_b = 0

for i_dye, dye in enumerate(dyes):
    dye_str = dye.replace("/", "-")

    # Discover all ground-truth files for this dye and parse z/d from the filename
    gt_all = sorted(
        glob.glob(str(save_folder / f"defocus_z*nm_d*nm_*{dye_str}*groundtruth*.csv"))
    )

    for gt_path in gt_all:
        fname = Path(gt_path).name
        m = _flag_re.search(fname)
        if not m:
            continue
        z_val = _parse_nm(m.group(1))
        d_val = _parse_nm(m.group(2))
        i_z   = _nearest_idx(z_offsets_nm,       z_val, tol=1.0)
        i_d   = _nearest_idx(coverslip_depths_nm, d_val, tol=10.0)
        if i_z is None or i_d is None:
            continue

        # Reconstruct flag prefix from the parsed values to find companion files
        flag_prefix = fname[: m.end()]   # everything up to and including the trailing "_"

        ip_files = sorted(glob.glob(str(save_folder / f"{flag_prefix}*{dye_str}*input_parameters*.csv")))
        h5_path  = save_folder / f"{flag_prefix}LM_method_{dye_str}_rawresults.h5"

        if not ip_files or not h5_path.exists():
            continue

        gt    = pd.read_csv(gt_path)
        gt_px = np.vstack([gt["x0"].to_numpy() / pixel_size_nm,
                           gt["y0"].to_numpy() / pixel_size_nm]).T

        dye_BGR     = pd.read_csv(ip_files[0]).to_numpy()[0][-3:]
        colour_true = (dye_BGR / dye_BGR.sum()).reshape(1, 3)

        df_raw = pd.read_hdf(str(h5_path), key="data")

        for i_ph in range(len(n_photon_space)):
            subset = df_raw[df_raw["photon_level"] == i_ph]
            if len(subset) == 0:
                continue

            xc = subset["xc"].to_numpy()
            yc = subset["yc"].to_numpy()
            filt = (
                (xc >= 0) & (yc >= 0) &
                (subset["s_x"].to_numpy() > 0) &
                (subset["s_y"].to_numpy() > 0) &
                (xc <= image_dims) & (yc <= image_dims)
            )
            if filt.sum() < 2:
                continue

            ex = (xc[filt] - gt_px[filt, 0]) * pixel_size_nm
            ey = (yc[filt] - gt_px[filt, 1]) * pixel_size_nm
            bx, by = float(np.nanmean(ex)), float(np.nanmean(ey))
            da_defocus_bias[i_dye, i_z, i_d, i_ph, 0] = np.sqrt((bx**2 + by**2) / 2)

            abgr = np.vstack([
                subset["A_B"].to_numpy()[filt],
                subset["A_G"].to_numpy()[filt],
                subset["A_R"].to_numpy()[filt],
            ]).T
            row_sums = abgr.sum(axis=1, keepdims=True)
            with np.errstate(divide="ignore", invalid="ignore"):
                abgr_norm = np.where(row_sums > 0, abgr / row_sums, np.nan)
            mean_colour = np.nanmean(abgr_norm, axis=0, keepdims=True)
            da_defocus_bias[i_dye, i_z, i_d, i_ph, 1] = float(
                cdist(mean_colour, colour_true)[0, 0]
            )
        n_loaded_b += 1

n_filled_b = int(np.sum(~np.isnan(da_defocus_bias.sel(metric="bias_xy").values)))
print(f"Loaded {n_loaded_b} H5 files → {n_filled_b} grid cells filled "
      f"({n_filled_b / da_defocus_bias.sel(metric='bias_xy').size * 100:.1f} %)")
da_defocus_bias.to_netcdf(str(save_folder / "defocus_bias.nc"))
print(f"bias_xy  : {float(da_defocus_bias.sel(metric='bias_xy').min()):.2f}–"
      f"{float(da_defocus_bias.sel(metric='bias_xy').max()):.2f} nm")
print(f"col. bias: {float(da_defocus_bias.sel(metric='colour_bias').min()):.4f}–"
      f"{float(da_defocus_bias.sel(metric='colour_bias').max()):.4f}")
# Out:
# Loaded 63 H5 files → 6300 grid cells filled (100.0 %)
# bias_xy  : 0.00–26.58 nm
# col. bias: 0.0010–0.3655

# %%
# ── Figure 6a: position bias — bias vs photons ───────────────────────────────
metric = "bias_xy"

fig, axs = plotter.two_column_plot(nrows=1, ncols=len(dyes),
                                    width_ratios=np.ones(len(dyes)))
for i_c, dye in enumerate(dyes):
    ax = axs[i_c]
    Z = da_defocus_bias.isel(dye=i_c, coverslip_nm=0).sel(metric=metric).values
    for i_z, z_nm_val in enumerate(z_offsets_nm[10:]):
        if i_z % 2 == 0:
            ax = plotter.line_plot(ax, n_photon_space, Z[i_z+10, :],
                                   color=z_colors[i_z], label=f'{z_nm_val:+.0f} nm')
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.set_xlabel(r'$N_{\mathrm{photons}}$', fontsize=fs)
    ax.set_ylabel(
        r'Position bias $\sqrt{(\bar{\epsilon}_x^2+\bar{\epsilon}_y^2)/2}$ / nm'
        if i_c == 0 else '', fontsize=fs)
    ax.set_title(dye_labels[dye], fontsize=fs)
    ax.tick_params(labelsize=fs - 1)
    ax.set_xlim([np.min(n_photon_space), np.max(n_photon_space)])

sm = plt.cm.ScalarMappable(cmap=_z_cmap, norm=_z_norm)
sm.set_array([])
fig.colorbar(sm, ax=list(axs), label='Defocus / nm', shrink=0.7, aspect=30, pad=0.02)
plotter.save_or_show(fig, save_path=str(save_folder / "position_bias_lines.svg"))
# Out:
# INFO:src.PlottingBase:Plot saved to: /scratch/sycamore-asap/ASAP_Members_Other_Imaging_Data/JSB/Simulation/Z_Position_Effect/position_bias_lines.svg

# %%
# ── Figure 6b: colour bias — bias vs photons ─────────────────────────────────
metric = "colour_bias"

fig, axs = plotter.two_column_plot(nrows=1, ncols=len(dyes),
                                    width_ratios=np.ones(len(dyes)))
for i_c, dye in enumerate(dyes):
    ax = axs[i_c]
    Z = da_defocus_bias.isel(dye=i_c, coverslip_nm=0).sel(metric=metric).values
    for i_z, z_nm_val in enumerate(z_offsets_nm[10:]):
        if i_z % 2 == 0:
            ax = plotter.line_plot(ax, n_photon_space, Z[i_z+10, :],
                                   color=z_colors[i_z], label=f'{z_nm_val:+.0f} nm')
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.set_xlabel(r'$N_{\mathrm{photons}}$', fontsize=fs)
    ax.set_ylabel(
        r'Colour bias $||\bar{f}_{\mathrm{fit}} - f_{\mathrm{true}}||$'
        if i_c == 0 else '', fontsize=fs)
    ax.set_title(dye_labels[dye], fontsize=fs)
    ax.tick_params(labelsize=fs - 1)
    ax.set_xlim([np.min(n_photon_space), np.max(n_photon_space)])

sm = plt.cm.ScalarMappable(cmap=_z_cmap, norm=_z_norm)
sm.set_array([])
fig.colorbar(sm, ax=list(axs), label='Defocus / nm', shrink=0.7, aspect=30, pad=0.02)
plotter.save_or_show(fig, save_path=str(save_folder / "colour_bias_lines.svg"))
# Out:
# INFO:src.PlottingBase:Plot saved to: /scratch/sycamore-asap/ASAP_Members_Other_Imaging_Data/JSB/Simulation/Z_Position_Effect/colour_bias_lines.svg

# %% [markdown]
# ## Comparative Degradation vs In-Focus Baseline
#
# How much worse does each metric get relative to the **in-focus (z = 0 nm) baseline**?
#
# **Precision metrics** (`sigma_xy`, `colour_dist`) shown as a **fold ratio**
# `metric(z) / metric(z = 0)`: 1 = identical to in-focus, 2 = twice as bad.
#
# **Bias metrics** (`bias_xy`, `colour_bias`) shown as the **absolute increase**
# `metric(z) − metric(z = 0)`, since the in-focus bias is near zero.
#
# One line per defocus value; colour encodes defocus via the same coolwarm scale.

# %%
import xarray as xr
import matplotlib.colors as mcolors

# ── Load precision and bias arrays from disk ──────────────────────────────────
da_defocus      = xr.open_dataarray(str(save_folder / "defocus_sweep.nc"))
da_defocus_bias = xr.open_dataarray(str(save_folder / "defocus_bias.nc"))
print(f"Precision : {da_defocus.dims}  {da_defocus.shape}")
print(f"Bias      : {da_defocus_bias.dims}  {da_defocus_bias.shape}")

# %%
# ── Figure 8: precision fold-degradation vs in-focus (z = 0 nm) ──────────────
baseline_p    = da_defocus.sel(z_nm=0.0)
ratio_defocus = da_defocus / baseline_p.where(baseline_p > 1e-10)

_z  = da_defocus.coords["z_nm"].values
_ph = da_defocus.coords["n_photons"].values

metric_list_p = ["sigma_xy",                               "colour_dist"]
ylabels_p     = [r"$\sigma_{xy}$ / $\sigma_{xy}$(z=0)",
                 r"$\sigma_{\mathrm{colour}}$ / $\sigma_{\mathrm{colour}}$(z=0)"]
save_names_p  = ["sigma_xy_fold_degradation_lines.svg",
                 "colour_dist_fold_degradation_lines.svg"]

for metric, ylabel, save_name in zip(metric_list_p, ylabels_p, save_names_p):
    fig, axs = plotter.two_column_plot(nrows=1, ncols=len(dyes),
                                        width_ratios=np.ones(len(dyes)))
    for i_c, dye in enumerate(dyes):
        ax = axs[i_c]
        Z = ratio_defocus.isel(dye=i_c, coverslip_nm=0).sel(metric=metric).values
        for i_z, z_nm_val in enumerate(_z):
            ax = plotter.line_plot(ax, _ph, Z[i_z, :], color=z_colors[i_z])
        ax.set_yscale("log")
        ax.set_xscale("log")
        ax.set_xlabel(r'$N_{\mathrm{photons}}$', fontsize=fs)
        ax.set_ylabel(ylabel if i_c == 0 else '', fontsize=fs)
        ax.set_title(dye_labels[dye], fontsize=fs)
        ax.tick_params(labelsize=fs - 1)
        ax.set_xlim([np.min(_ph), np.max(_ph)])
    sm = plt.cm.ScalarMappable(cmap=_z_cmap, norm=_z_norm)
    sm.set_array([])
    fig.colorbar(sm, ax=list(axs), label='Defocus / nm', shrink=0.7, aspect=30, pad=0.02)
    fig.tight_layout(pad=0.4)
    plotter.save_or_show(fig, save_path=str(save_folder / save_name))

# %%
# ── Figure 9: bias absolute increase vs in-focus (z = 0 nm) baseline ─────────
baseline_b = da_defocus_bias.sel(z_nm=0.0)
increase_b = da_defocus_bias - baseline_b

_z_b  = da_defocus_bias.coords["z_nm"].values
_ph_b = da_defocus_bias.coords["n_photons"].values

metric_list_b = ["bias_xy",                        "colour_bias"]
ylabels_b     = [r"Extra pos. bias / nm",
                 r"Extra colour bias $\Delta||\bar{f}_{\mathrm{fit}} - f_{\mathrm{true}}||$"]
save_names_b  = ["bias_xy_absolute_increase_lines.svg",
                 "colour_bias_absolute_increase_lines.svg"]

for metric, ylabel, save_name in zip(metric_list_b, ylabels_b, save_names_b):
    fig, axs = plotter.two_column_plot(nrows=1, ncols=len(dyes),
                                        width_ratios=np.ones(len(dyes)))
    for i_c, dye in enumerate(dyes):
        ax = axs[i_c]
        Z = increase_b.isel(dye=i_c, coverslip_nm=0).sel(metric=metric).values
        for i_z, z_nm_val in enumerate(_z_b):
            ax = plotter.line_plot(ax, _ph_b, Z[i_z, :], color=z_colors[i_z])
        ax.set_yscale("log")
        ax.set_xscale("log")
        ax.set_xlabel(r'$N_{\mathrm{photons}}$', fontsize=fs)
        ax.set_ylabel(ylabel if i_c == 0 else '', fontsize=fs)
        ax.set_title(dye_labels[dye], fontsize=fs)
        ax.tick_params(labelsize=fs - 1)
        ax.set_xlim([np.min(_ph_b), np.max(_ph_b)])
    sm = plt.cm.ScalarMappable(cmap=_z_cmap, norm=_z_norm)
    sm.set_array([])
    fig.colorbar(sm, ax=list(axs), label='Defocus / nm', shrink=0.7, aspect=30, pad=0.02)
    fig.tight_layout(pad=0.4)
    plotter.save_or_show(fig, save_path=str(save_folder / save_name))
