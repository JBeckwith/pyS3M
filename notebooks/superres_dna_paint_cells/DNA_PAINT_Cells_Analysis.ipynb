# %%
import numpy as np  # import numerical python
import matplotlib.pyplot as plt  # import plotting functions
import seaborn as sns  # import nicer plotting functions
import polars as pl  # import polars to import data
import tifffile as tiff
from tifffile import imwrite, imread
from copy import deepcopy
import os
import time

import sys

sys.path.append("../..")

from src import IOFunctions

IO = IOFunctions.IO_Functions()

# from src import Multicolour_Simulation_Functions

# MSF = Multicolour_Simulation_Functions.MultiC_Sim_Funcs()

from src import PlottingFunctions

plotter = PlottingFunctions.Plotter()

from src import ImageAnalysisFunctions

I_AF = ImageAnalysisFunctions.Image_Analysis_Functions()

from src import sCMOSFunctions

sCMOS = sCMOSFunctions.sCMOS_Functions()

from src import PSFFunctions

PSF = PSFFunctions.PSF_Functions()

from src import SpectralFunctions

S_F = SpectralFunctions.Spectral_Funcs()

from src import MaskFunctions

M_F = MaskFunctions.Mask_Functions()

from src import SpotDetectionFunctions

SD_F = SpotDetectionFunctions.SpotDetection_Functions()

from src import SR_Functions

SupRes_F = SR_Functions.SuperRes_Functions()

import HelperFunctions

H_F = HelperFunctions.Helper_Functions()

import DriftCorrectionFunctions as DCF
# Out:
# /tmp/ipykernel_761243/3496390403.py:25: DeprecationWarning: PlottingFunctions.Plotter is deprecated and will be removed in a future version. Use PlottingBase.PublicationPlotter directly instead.
#   plotter = PlottingFunctions.Plotter()

# %%
data_folder = "../../Camera_Calibrations/Ximea_Camera"
gain_map = IO.read_tiff(os.path.join(data_folder, "gain.tif"))
offset_map = IO.read_tiff(os.path.join(data_folder, "offset.tif"))
variance = IO.read_tiff(os.path.join(data_folder, "variance.tif"))
read_noise = IO.read_tiff(os.path.join(data_folder, "readnoise.tif"))
rqe = IO.read_tiff(os.path.join(data_folder, "rqe.tif"))
R, G, B, wavelength = S_F.getpixelefficiency()

pixel_QYs = np.vstack([B, G, R])
camera_parameters = {}
camera_parameters["pixel_QYs"] = pixel_QYs
camera_parameters["pixel_order"] = ["B", "G", "R"]
camera_parameters["pixel_order_indices"] = [0, 1, 2]

# %%
import types

smoothing_function = types.SimpleNamespace()
smoothing_function.args = {"sigma": 1.5}
smoothing_function.extent = 1.5
smoothing_function.smoothing_function = sCMOS.gaussian_filter_stack
smoothing_function.data_arg = "image"

# %%
image_folder = "/scratch/sycamore-asap/2026_Multicolour_Paper/Data/Ximea/MassiveCells/250pMATTO655_750pMCy3B_20perc561_60mW638_1"
image_files = H_F.file_search(image_folder, ".tif", "")
metadata_files = H_F.file_search(image_folder, 'metadata', '')

# %%
# play around with pfa to find a good parameter
pfa = 1e-3
sigma = 1.5
fraction_true=0.2
peak_wavelength = 0.65
frame_index = 10
fig, axs = SupRes_F.example_spots_singleframe(image_folder, pfa=pfa, sigma=sigma, fraction_true=fraction_true, 
                                              frame_index=frame_index, variance=variance, read_noise=read_noise,
                                             rqe=rqe, offset_map=offset_map, gain_map=gain_map, peak_wavelength=peak_wavelength)
plt.show()
# Out:
#                                                                                 ?, ?it/s]

# %%
SupRes_F.fit_imaging_data(
    image_folder,
    smoothing_function,
    gain_map,
    offset_map,
    rqe,
    read_noise,
    variance=variance,
    pfa=pfa,
    ROI_size=12,
    peak_wavelength=peak_wavelength,
    fraction_true=fraction_true,
    sigma=sigma,
    NA=1.49,
    pixel_size=0.069,
    image_type=".tif",
)
# Out:
# Processing file 1/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1186852 puncta across all chunks                                        ?, ?it/s]
# Processing file 2/20: 3114 frames in chunks of 1000                             ?, ?it/s]
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1154394 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 697,794 total localizations
#   Sorted by frame (range: 0-6227)
#   Rewritten sorted data to Localisations.h5
# Processing file 3/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1132202 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 1,033,362 total localizations
#   Sorted by frame (range: 0-9341)
#   Rewritten sorted data to Localisations.h5
# Processing file 4/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1111906 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 1,362,547 total localizations
#   Sorted by frame (range: 0-12455)
#   Rewritten sorted data to Localisations.h5
# Processing file 5/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1091138 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 1,686,118 total localizations
#   Sorted by frame (range: 0-15569)
#   Rewritten sorted data to Localisations.h5
# Processing file 6/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1081273 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 2,003,057 total localizations
#   Sorted by frame (range: 0-18683)
#   Rewritten sorted data to Localisations.h5
# Processing file 7/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1054248 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 2,310,858 total localizations
#   Sorted by frame (range: 0-21797)
#   Rewritten sorted data to Localisations.h5
# Processing file 8/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1033246 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 2,613,166 total localizations
#   Sorted by frame (range: 0-24911)
#   Rewritten sorted data to Localisations.h5
# Processing file 9/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1012880 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 2,908,722 total localizations
#   Sorted by frame (range: 0-28025)
#   Rewritten sorted data to Localisations.h5
# Processing file 10/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 1000609 puncta across all chunks                                        ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 3,199,506 total localizations
#   Sorted by frame (range: 0-31139)
#   Rewritten sorted data to Localisations.h5
# Processing file 11/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 984617 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 3,486,937 total localizations
#   Sorted by frame (range: 0-34253)
#   Rewritten sorted data to Localisations.h5
# Processing file 12/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 972286 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 3,768,190 total localizations
#   Sorted by frame (range: 0-37367)
#   Rewritten sorted data to Localisations.h5
# Processing file 13/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 967357 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 4,045,531 total localizations
#   Sorted by frame (range: 0-40481)
#   Rewritten sorted data to Localisations.h5
# Processing file 14/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 957441 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 4,319,394 total localizations
#   Sorted by frame (range: 0-43595)
#   Rewritten sorted data to Localisations.h5
# Processing file 15/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 949878 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 4,590,543 total localizations
#   Sorted by frame (range: 0-46709)
#   Rewritten sorted data to Localisations.h5
# Processing file 16/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 946760 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 4,860,444 total localizations
#   Sorted by frame (range: 0-49823)
#   Rewritten sorted data to Localisations.h5
# Processing file 17/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 938094 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 5,127,680 total localizations
#   Sorted by frame (range: 0-52937)
#   Rewritten sorted data to Localisations.h5
# Processing file 18/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 920209 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 5,387,406 total localizations
#   Sorted by frame (range: 0-56051)
#   Rewritten sorted data to Localisations.h5
# Processing file 19/20: 3114 frames in chunks of 1000
#   Processing chunk: frames 0-999
#   Processing chunk: frames 1000-1999                                            ?, ?it/s]
#   Processing chunk: frames 2000-2999                                            ?, ?it/s]
#   Processing chunk: frames 3000-3113                                            ?, ?it/s]
#   Found 910634 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 5,643,098 total localizations
#   Sorted by frame (range: 0-59165)
#   Rewritten sorted data to Localisations.h5
# Processing file 20/20: 834 frames in chunks of 1000
#   Processing chunk: frames 0-833
#   Found 241834 puncta across all chunks                                         ?, ?it/s]
# Sorting appended HDF5 file by frame: Localisations.h5                           ?, ?it/s]
#   Read 5,711,358 total localizations
#   Sorted by frame (range: 0-59999)
#   Rewritten sorted data to Localisations.h5
